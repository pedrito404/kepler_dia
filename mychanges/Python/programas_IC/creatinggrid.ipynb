# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shutil

# %%
a = !find Kepler56_modelo1/Kepler56bcd/follow*
b = !find Kepler56_modelo2/Kepler56bcd/follow* 
c = !find Kepler-9_2/Kepler9dbc/follow*

# %%
a
# Out:
# ['Kepler56_modelo1/Kepler56bcd/follow( -2).out',
#  'Kepler56_modelo1/Kepler56bcd/follow( -3).out',
#  'Kepler56_modelo1/Kepler56bcd/follow( -4).out']

# %% [markdown]
# # Ordem crescente de semi-eixo

# %% [raw]
# Kepler56 -> b; c e d
#
# Kepler9 -> d; b e c

# %%
k56_1_b = pd.read_csv(a[0],delim_whitespace=True,header =None,engine='c')
k56_1_c = pd.read_csv(a[1],delim_whitespace=True,header =None,engine='c')
k56_1_d = pd.read_csv(a[2],delim_whitespace=True,header =None,engine='c')

k56_2_b = pd.read_csv(b[0],delim_whitespace=True,header =None,engine='c')
k56_2_c = pd.read_csv(b[1],delim_whitespace=True,header =None,engine='c')
k56_2_d = pd.read_csv(b[2],delim_whitespace=True,header =None,engine='c')

k9_d = pd.read_csv(c[0],delim_whitespace=True,header =None,engine='c')
k9_b = pd.read_csv(c[1],delim_whitespace=True,header =None,engine='c')
k9_c = pd.read_csv(c[2],delim_whitespace=True,header =None,engine='c')

# %%
k56_1_b.columns=['t','a','e','i','capom','omega','capm','peri','apo','obar']
k56_1_c.columns=['t','a','e','i','capom','omega','capm','peri','apo','obar']
k56_1_d.columns=['t','a','e','i','capom','omega','capm','peri','apo','obar']
k56_2_b.columns=['t','a','e','i','capom','omega','capm','peri','apo','obar']
k56_2_c.columns=['t','a','e','i','capom','omega','capm','peri','apo','obar']
k56_2_d.columns=['t','a','e','i','capom','omega','capm','peri','apo','obar']
k9_b.columns=['t','a','e','i','capom','omega','capm','peri','apo','obar']
k9_c.columns=['t','a','e','i','capom','omega','capm','peri','apo','obar']
k9_d.columns=['t','a','e','i','capom','omega','capm','peri','apo','obar']

# %%
delta_k56_1_b = np.std(k56_1_b['a'],ddof=1)
delta_k56_1_c = np.std(k56_1_c['a'],ddof=1)
delta_k56_1_d = np.std(k56_1_d['a'],ddof=1)
delta_k56_2_b = np.std(k56_2_b['a'],ddof=1)
delta_k56_2_c = np.std(k56_2_c['a'],ddof=1)
delta_k56_2_d = np.std(k56_2_d['a'],ddof=1)
delta_k9_d = np.std(k9_d['a'],ddof=1)
delta_k9_b = np.std(k9_b['a'],ddof=1)
delta_k9_c = np.std(k9_c['a'],ddof=1)

# %%
print('k56_1_b é ',delta_k56_1_b)
print('k56_1_c é ',delta_k56_1_c)
print('k56_1_d é ',delta_k56_1_d)
print('k56_2_b é ',delta_k56_2_b)
print('k56_2_c é ',delta_k56_2_c)
print('k56_2_d é ',delta_k56_2_d)
print('k9_b é ',delta_k9_b)
print('k9_c é ',delta_k9_c)
print('k9_d é ',delta_k9_d)
# Out:
# k56_1_b é  8.034316210873132e-05
# k56_1_c é  4.7547852950144546e-05
# k56_1_d é  0.00466226393816321
# k56_2_b é  8.032902790851969e-05
# k56_2_c é  4.747569489581475e-05
# k56_2_d é  0.004476368005978399
# k9_b é  0.00015311827195081516
# k9_c é  0.0005560546616896461
# k9_d é  2.7075227224947325e-16

# %%
semi_k56_1_b = np.mean(k56_1_b['a'])
semi_k56_1_c = np.mean(k56_1_c['a'])
semi_k56_1_d = np.mean(k56_1_d['a'])
semi_k56_2_b = np.mean(k56_2_b['a'])
semi_k56_2_c = np.mean(k56_2_c['a'])
semi_k56_2_d = np.mean(k56_2_d['a'])
semi_k9_d = np.mean(k9_d['a'])
semi_k9_b = np.mean(k9_b['a'])
semi_k9_c = np.mean(k9_c['a'])

print('k56_1_b é ',semi_k56_1_b)
print('k56_1_c é ',semi_k56_1_c)
print('k56_1_d é ',semi_k56_1_d)
print('k56_2_b é ',semi_k56_2_b)
print('k56_2_c é ',semi_k56_2_c)
print('k56_2_d é ',semi_k56_2_d)
print('k9_b é ',semi_k9_b)
print('k9_c é ',semi_k9_c)
print('k9_d é ',semi_k9_d)
# Out:
# k56_1_b é  0.10284342565742925
# k56_1_c é  0.16513452654733274
# k56_1_d é  2.1506488951104914
# k56_2_b é  0.1028437156284321
# k56_2_c é  0.1651343065693305
# k56_2_d é  2.150697660233976
# k9_b é  0.14102319999999924
# k9_c é  0.22403289999999998
# k9_d é  0.027300000000000272

# %% [markdown]
# # Definindo número de pontos

# %%
npoints = 100

# %% [markdown]
# # Definindo espaçamentos

# %%
#Aqui defini que as excentricidades escolhidas vao de 0.1 a 0.1 - [0.1,0.2,0.3,0.4] foram as escolhidas

esp_exc = 0.1

#Aqui variei o semi eixo de semi eixo medio menos sigma até semi eixo medio

esp_k56_1_b = (2*delta_k56_1_b)/(npoints-1)
esp_k56_1_c = (2*delta_k56_1_c)/(npoints-1)
esp_k56_1_d = (2*delta_k56_1_d)/(npoints-1)

esp_k56_2_b = (2*delta_k56_2_b)/(npoints-1)
esp_k56_2_c = (2*delta_k56_2_c)/(npoints-1)
esp_k56_2_d = (2*delta_k56_2_d)/(npoints-1)

esp_k9_d = (2*delta_k9_d)/(npoints-1)
esp_k9_b = (2*delta_k9_b)/(npoints-1)
esp_k9_c = (2*delta_k9_c)/(npoints-1)

# %% [markdown]
# # Compilando tudo num só for

# %%
#os.removedirs nao deleta se tiver arquivos mas shutil.rmtree sim
try:
    os.makedirs('grades/k56_mod1/Em_b/M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_b/M60')
    os.makedirs('grades/k56_mod1/Em_b/M60')
try:
    os.makedirs('grades/k56_mod1/Em_b/2M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_b/2M60')
    os.makedirs('grades/k56_mod1/Em_b/2M60')
try:
    os.makedirs('grades/k56_mod1/Em_b/3M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_b/3M60')
    os.makedirs('grades/k56_mod1/Em_b/3M60')
try:
    os.makedirs('grades/k56_mod1/Em_b/4M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_b/4M60')
    os.makedirs('grades/k56_mod1/Em_b/4M60')

try:
    os.makedirs('grades/k56_mod2/Em_b/M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_b/M60')
    os.makedirs('grades/k56_mod2/Em_b/M60')
try:
    os.makedirs('grades/k56_mod2/Em_b/2M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_b/2M60')
    os.makedirs('grades/k56_mod2/Em_b/2M60')
try:
    os.makedirs('grades/k56_mod2/Em_b/3M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_b/3M60')
    os.makedirs('grades/k56_mod2/Em_b/3M60')
try:
    os.makedirs('grades/k56_mod2/Em_b/4M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_b/4M60')
    os.makedirs('grades/k56_mod2/Em_b/4M60')
    
try:
    os.makedirs('grades/k56_mod1/Em_b/omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_b/omega60')
    os.makedirs('grades/k56_mod1/Em_b/omega60')
try:
    os.makedirs('grades/k56_mod1/Em_b/2omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_b/2omega60')
    os.makedirs('grades/k56_mod1/Em_b/2omega60')
try:
    os.makedirs('grades/k56_mod1/Em_b/3omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_b/3omega60')
    os.makedirs('grades/k56_mod1/Em_b/3omega60')
try:
    os.makedirs('grades/k56_mod1/Em_b/4omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_b/4omega60')
    os.makedirs('grades/k56_mod1/Em_b/4omega60')
    
try:
    os.makedirs('grades/k56_mod2/Em_b/omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_b/omega60')
    os.makedirs('grades/k56_mod2/Em_b/omega60')
try:
    os.makedirs('grades/k56_mod2/Em_b/2omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_b/2omega60')
    os.makedirs('grades/k56_mod2/Em_b/2omega60')
try:
    os.makedirs('grades/k56_mod2/Em_b/3omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_b/3omega60')
    os.makedirs('grades/k56_mod2/Em_b/3omega60')
try:
    os.makedirs('grades/k56_mod2/Em_b/4omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_b/4omega60')
    os.makedirs('grades/k56_mod2/Em_b/4omega60')
    
try:
    os.makedirs('grades/k56_mod1/Em_c/M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_c/M60')
    os.makedirs('grades/k56_mod1/Em_c/M60')
try:
    os.makedirs('grades/k56_mod1/Em_c/2M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_c/2M60')
    os.makedirs('grades/k56_mod1/Em_c/2M60')
try:
    os.makedirs('grades/k56_mod1/Em_c/3M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_c/3M60')
    os.makedirs('grades/k56_mod1/Em_c/3M60')
try:
    os.makedirs('grades/k56_mod1/Em_c/4M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_c/4M60')
    os.makedirs('grades/k56_mod1/Em_c/4M60')
    
try:
    os.makedirs('grades/k56_mod2/Em_c/M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_c/M60')
    os.makedirs('grades/k56_mod2/Em_c/M60')
try:
    os.makedirs('grades/k56_mod2/Em_c/2M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_c/2M60')
    os.makedirs('grades/k56_mod2/Em_c/2M60')
try:
    os.makedirs('grades/k56_mod2/Em_c/3M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_c/3M60')
    os.makedirs('grades/k56_mod2/Em_c/3M60')
try:
    os.makedirs('grades/k56_mod2/Em_c/4M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_c/4M60')
    os.makedirs('grades/k56_mod2/Em_c/4M60')
    
try:
    os.makedirs('grades/k56_mod1/Em_c/omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_c/omega60')
    os.makedirs('grades/k56_mod1/Em_c/omega60')
try:
    os.makedirs('grades/k56_mod1/Em_c/2omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_c/2omega60')
    os.makedirs('grades/k56_mod1/Em_c/2omega60')
try:
    os.makedirs('grades/k56_mod1/Em_c/3omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_c/3omega60')
    os.makedirs('grades/k56_mod1/Em_c/3omega60')
try:
    os.makedirs('grades/k56_mod1/Em_c/4omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_c/4omega60')
    os.makedirs('grades/k56_mod1/Em_c/4omega60')

try:
    os.makedirs('grades/k56_mod2/Em_c/omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_c/omega60')
    os.makedirs('grades/k56_mod2/Em_c/omega60')
try:
    os.makedirs('grades/k56_mod2/Em_c/2omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_c/2omega60')
    os.makedirs('grades/k56_mod2/Em_c/2omega60')
try:
    os.makedirs('grades/k56_mod2/Em_c/3omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_c/3omega60')
    os.makedirs('grades/k56_mod2/Em_c/3omega60')
try:
    os.makedirs('grades/k56_mod2/Em_c/4omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_c/4omega60')
    os.makedirs('grades/k56_mod2/Em_c/4omega60')
    
try:
    os.makedirs('grades/k56_mod1/Em_d/M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_d/M60')
    os.makedirs('grades/k56_mod1/Em_d/M60')
try:
    os.makedirs('grades/k56_mod1/Em_d/2M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_d/2M60')
    os.makedirs('grades/k56_mod1/Em_d/2M60')
try:
    os.makedirs('grades/k56_mod1/Em_d/3M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_d/3M60')
    os.makedirs('grades/k56_mod1/Em_d/3M60')
try:
    os.makedirs('grades/k56_mod1/Em_d/4M60')
except:
    shutil.rmtree('grades/k56_mod1/Em_d/4M60')
    os.makedirs('grades/k56_mod1/Em_d/4M60')
    
try:
    os.makedirs('grades/k56_mod2/Em_d/M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_d/M60')
    os.makedirs('grades/k56_mod2/Em_d/M60')
try:
    os.makedirs('grades/k56_mod2/Em_d/2M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_d/2M60')
    os.makedirs('grades/k56_mod2/Em_d/2M60')
try:
    os.makedirs('grades/k56_mod2/Em_d/3M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_d/3M60')
    os.makedirs('grades/k56_mod2/Em_d/3M60')
try:
    os.makedirs('grades/k56_mod2/Em_d/4M60')
except:
    shutil.rmtree('grades/k56_mod2/Em_d/4M60')
    os.makedirs('grades/k56_mod2/Em_d/4M60')
    
try:
    os.makedirs('grades/k56_mod1/Em_d/omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_d/omega60')
    os.makedirs('grades/k56_mod1/Em_d/omega60')
try:
    os.makedirs('grades/k56_mod1/Em_d/2omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_d/2omega60')
    os.makedirs('grades/k56_mod1/Em_d/2omega60')
try:
    os.makedirs('grades/k56_mod1/Em_d/3omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_d/3omega60')
    os.makedirs('grades/k56_mod1/Em_d/3omega60')
try:
    os.makedirs('grades/k56_mod1/Em_d/4omega60')
except:
    shutil.rmtree('grades/k56_mod1/Em_d/4omega60')
    os.makedirs('grades/k56_mod1/Em_d/4omega60')
    
try:
    os.makedirs('grades/k56_mod2/Em_d/omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_d/omega60')
    os.makedirs('grades/k56_mod2/Em_d/omega60')
try:
    os.makedirs('grades/k56_mod2/Em_d/2omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_d/2omega60')
    os.makedirs('grades/k56_mod2/Em_d/2omega60')
try:
    os.makedirs('grades/k56_mod2/Em_d/3omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_d/3omega60')
    os.makedirs('grades/k56_mod2/Em_d/3omega60')
try:
    os.makedirs('grades/k56_mod2/Em_d/4omega60')
except:
    shutil.rmtree('grades/k56_mod2/Em_d/4omega60')
    os.makedirs('grades/k56_mod2/Em_d/4omega60')
    
try:
    os.makedirs('grades/k9/Em_d/M60')
except:
    shutil.rmtree('grades/k9/Em_d/M60')
    os.makedirs('grades/k9/Em_d/M60')
try:
    os.makedirs('grades/k9/Em_d/2M60')
except:
    shutil.rmtree('grades/k9/Em_d/2M60')
    os.makedirs('grades/k9/Em_d/2M60')
try:
    os.makedirs('grades/k9/Em_d/3M60')
except:
    shutil.rmtree('grades/k9/Em_d/3M60')
    os.makedirs('grades/k9/Em_d/3M60')
try:
    os.makedirs('grades/k9/Em_d/4M60')
except:
    shutil.rmtree('grades/k9/Em_d/4M60')
    os.makedirs('grades/k9/Em_d/4M60')
    
try:
    os.makedirs('grades/k9/Em_d/omega60')
except:
    shutil.rmtree('grades/k9/Em_d/omega60')
    os.makedirs('grades/k9/Em_d/omega60')
try:
    os.makedirs('grades/k9/Em_d/2omega60')
except:
    shutil.rmtree('grades/k9/Em_d/2omega60')
    os.makedirs('grades/k9/Em_d/2omega60')
try:
    os.makedirs('grades/k9/Em_d/3omega60')
except:
    shutil.rmtree('grades/k9/Em_d/3omega60')
    os.makedirs('grades/k9/Em_d/3omega60')
try:
    os.makedirs('grades/k9/Em_d/4omega60')
except:
    shutil.rmtree('grades/k9/Em_d/4omega60')
    os.makedirs('grades/k9/Em_d/4omega60')

try:
    os.makedirs('grades/k9/Em_b/M60')
except:
    shutil.rmtree('grades/k9/Em_b/M60')
    os.makedirs('grades/k9/Em_b/M60')
try:
    os.makedirs('grades/k9/Em_b/2M60')
except:
    shutil.rmtree('grades/k9/Em_b/2M60')
    os.makedirs('grades/k9/Em_b/2M60')
try:
    os.makedirs('grades/k9/Em_b/3M60')
except:
    shutil.rmtree('grades/k9/Em_b/3M60')
    os.makedirs('grades/k9/Em_b/3M60')
try:
    os.makedirs('grades/k9/Em_b/4M60')
except:
    shutil.rmtree('grades/k9/Em_b/4M60')
    os.makedirs('grades/k9/Em_b/4M60')
    
try:
    os.makedirs('grades/k9/Em_b/omega60')
except:
    shutil.rmtree('grades/k9/Em_b/omega60')
    os.makedirs('grades/k9/Em_b/omega60')
try:
    os.makedirs('grades/k9/Em_b/2omega60')
except:
    shutil.rmtree('grades/k9/Em_b/2omega60')
    os.makedirs('grades/k9/Em_b/2omega60')
try:
    os.makedirs('grades/k9/Em_b/3omega60')
except:
    shutil.rmtree('grades/k9/Em_b/3omega60')
    os.makedirs('grades/k9/Em_b/3omega60')
try:
    os.makedirs('grades/k9/Em_b/4omega60')
except:
    shutil.rmtree('grades/k9/Em_b/4omega60')
    os.makedirs('grades/k9/Em_b/4omega60')
    
try:
    os.makedirs('grades/k9/Em_c/M60')
except:
    shutil.rmtree('grades/k9/Em_c/M60')
    os.makedirs('grades/k9/Em_c/M60')
try:
    os.makedirs('grades/k9/Em_c/2M60')
except:
    shutil.rmtree('grades/k9/Em_c/2M60')
    os.makedirs('grades/k9/Em_c/2M60')
try:
    os.makedirs('grades/k9/Em_c/3M60')
except:
    shutil.rmtree('grades/k9/Em_c/3M60')
    os.makedirs('grades/k9/Em_c/3M60')
try:
    os.makedirs('grades/k9/Em_c/4M60')
except:
    shutil.rmtree('grades/k9/Em_c/4M60')
    os.makedirs('grades/k9/Em_c/4M60')

try:
    os.makedirs('grades/k9/Em_c/omega60')
except:
    shutil.rmtree('grades/k9/Em_c/omega60')
    os.makedirs('grades/k9/Em_c/omega60')
try:
    os.makedirs('grades/k9/Em_c/2omega60')
except:
    shutil.rmtree('grades/k9/Em_c/2omega60')
    os.makedirs('grades/k9/Em_c/2omega60')
try:
    os.makedirs('grades/k9/Em_c/3omega60')
except:
    shutil.rmtree('grades/k9/Em_c/3omega60')
    os.makedirs('grades/k9/Em_c/3omega60')
try:
    os.makedirs('grades/k9/Em_c/4omega60')
except:
    shutil.rmtree('grades/k9/Em_c/4omega60')
    os.makedirs('grades/k9/Em_c/4omega60')

# %%
#criará 4 linhas com valores de excentricidade 0.1,0.2,0.3 e 0.4

for i in range(npoints):
    for j in range(1,5):
        
        tab1 = open('grades/k56_mod1/Em_b/M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab101 = open('grades/k56_mod1/Em_b/2M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab102 = open('grades/k56_mod1/Em_b/3M60/troiano%003d'%(i + npoints*(j-1)),'w')        
        tab103 = open('grades/k56_mod1/Em_b/4M60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab1.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab1.write(str(semi_k56_1_b - delta_k56_1_b + i*esp_k56_1_b) + '\n')
        tab1.write(str(j*esp_exc) +'\n')
        tab1.write('6.16'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'111.40305198651')        
        tab101.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab101.write(str(semi_k56_1_b - delta_k56_1_b + i*esp_k56_1_b) + '\n')
        tab101.write(str(j*esp_exc) +'\n')
        tab101.write('6.16'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'111.40305198651')
        tab102.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab102.write(str(semi_k56_1_b - delta_k56_1_b + i*esp_k56_1_b) + '\n')
        tab102.write(str(j*esp_exc) +'\n')
        tab102.write('6.16'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'111.40305198651')
        tab103.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab103.write(str(semi_k56_1_b - delta_k56_1_b + i*esp_k56_1_b) + '\n')
        tab103.write(str(j*esp_exc) +'\n')
        tab103.write('6.16'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'111.40305198651')
        
        tab1.close()
        tab101.close()
        tab102.close()
        tab103.close()

        tab2 = open('grades/k56_mod2/Em_b/M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab104 = open('grades/k56_mod2/Em_b/2M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab105 = open('grades/k56_mod2/Em_b/3M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab106 = open('grades/k56_mod2/Em_b/4M60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab2.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab2.write(str(semi_k56_2_b - delta_k56_2_b + i*esp_k56_2_b) + '\n')
        tab2.write(str(j*esp_exc) +'\n')
        tab2.write('6.16'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'111.40305198651')
        tab104.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab104.write(str(semi_k56_2_b - delta_k56_2_b + i*esp_k56_2_b) + '\n')
        tab104.write(str(j*esp_exc) +'\n')
        tab104.write('6.16'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'111.40305198651')
        tab105.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab105.write(str(semi_k56_2_b - delta_k56_2_b + i*esp_k56_2_b) + '\n')
        tab105.write(str(j*esp_exc) +'\n')
        tab105.write('6.16'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'111.40305198651')
        tab106.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab106.write(str(semi_k56_2_b - delta_k56_2_b + i*esp_k56_2_b) + '\n')
        tab106.write(str(j*esp_exc) +'\n')
        tab106.write('6.16'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'111.40305198651')
        
        tab2.close()
        tab104.close()
        tab105.close()
        tab106.close()

        tab3 = open('grades/k56_mod1/Em_b/omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab107 = open('grades/k56_mod1/Em_b/2omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab108 = open('grades/k56_mod1/Em_b/3omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab109 = open('grades/k56_mod1/Em_b/4omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab3.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab3.write(str(semi_k56_1_b - delta_k56_1_b + i*esp_k56_1_b) + '\n')
        tab3.write(str(j*esp_exc) +'\n')
        tab3.write('6.16'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'51.40305198651')
        tab107.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab107.write(str(semi_k56_1_b - delta_k56_1_b + i*esp_k56_1_b) + '\n')
        tab107.write(str(j*esp_exc) +'\n')
        tab107.write('6.16'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'51.40305198651')
        tab108.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab108.write(str(semi_k56_1_b - delta_k56_1_b + i*esp_k56_1_b) + '\n')
        tab108.write(str(j*esp_exc) +'\n')
        tab108.write('6.16'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'51.40305198651')
        tab109.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab109.write(str(semi_k56_1_b - delta_k56_1_b + i*esp_k56_1_b) + '\n')
        tab109.write(str(j*esp_exc) +'\n')
        tab109.write('6.16'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'51.40305198651')
        
        tab3.close()
        tab107.close()
        tab108.close()
        tab109.close()
        
        tab4 = open('grades/k56_mod2/Em_b/omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab110 = open('grades/k56_mod2/Em_b/2omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab111 = open('grades/k56_mod2/Em_b/3omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab112 = open('grades/k56_mod2/Em_b/4omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab4.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab4.write(str(semi_k56_2_b - delta_k56_2_b + i*esp_k56_2_b) + '\n')
        tab4.write(str(j*esp_exc) +'\n')
        tab4.write('6.16'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'51.40305198651')
        tab110.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab110.write(str(semi_k56_2_b - delta_k56_2_b + i*esp_k56_2_b) + '\n')
        tab110.write(str(j*esp_exc) +'\n')
        tab110.write('6.16'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'51.40305198651')
        tab111.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab111.write(str(semi_k56_2_b - delta_k56_2_b + i*esp_k56_2_b) + '\n')
        tab111.write(str(j*esp_exc) +'\n')
        tab111.write('6.16'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'51.40305198651')
        tab112.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab112.write(str(semi_k56_2_b - delta_k56_2_b + i*esp_k56_2_b) + '\n')
        tab112.write(str(j*esp_exc) +'\n')
        tab112.write('6.16'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'51.40305198651')    
    
        tab4.close()
        tab110.close()
        tab111.close()
        tab112.close()
        
        tab5 = open('grades/k56_mod1/Em_c/M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab113 = open('grades/k56_mod1/Em_c/2M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab114 = open('grades/k56_mod1/Em_c/3M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab115 = open('grades/k56_mod1/Em_c/4M60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab5.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab5.write(str(semi_k56_1_c - delta_k56_1_c + i*esp_k56_1_c) + '\n')
        tab5.write(str(j*esp_exc) +'\n')
        tab5.write('5.98'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'-118.0')
        tab113.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab113.write(str(semi_k56_1_c - delta_k56_1_c + i*esp_k56_1_c) + '\n')
        tab113.write(str(j*esp_exc) +'\n')
        tab113.write('5.98'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'-118.0')
        tab114.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab114.write(str(semi_k56_1_c - delta_k56_1_c + i*esp_k56_1_c) + '\n')
        tab114.write(str(j*esp_exc) +'\n')
        tab114.write('5.98'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'-118.0')
        tab115.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab115.write(str(semi_k56_1_c - delta_k56_1_c + i*esp_k56_1_c) + '\n')
        tab115.write(str(j*esp_exc) +'\n')
        tab115.write('5.98'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'-118.0')
   
        tab5.close()
        tab113.close()
        tab114.close()
        tab115.close()
        
        tab6 = open('grades/k56_mod2/Em_c/M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab116 = open('grades/k56_mod2/Em_c/2M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab117 = open('grades/k56_mod2/Em_c/3M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab118 = open('grades/k56_mod2/Em_c/4M60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab6.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab6.write(str(semi_k56_2_c - delta_k56_2_c + i*esp_k56_2_c) + '\n')
        tab6.write(str(j*esp_exc) +'\n')
        tab6.write('5.98'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'-118.0')
        tab116.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab116.write(str(semi_k56_2_c - delta_k56_2_c + i*esp_k56_2_c) + '\n')
        tab116.write(str(j*esp_exc) +'\n')
        tab116.write('5.98'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'-118.0')
        tab117.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab117.write(str(semi_k56_2_c - delta_k56_2_c + i*esp_k56_2_c) + '\n')
        tab117.write(str(j*esp_exc) +'\n')
        tab117.write('5.98'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'-118.0')
        tab118.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab118.write(str(semi_k56_2_c - delta_k56_2_c + i*esp_k56_2_c) + '\n')
        tab118.write(str(j*esp_exc) +'\n')
        tab118.write('5.98'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'-118.0')
        
        tab6.close()
        tab116.close()
        tab117.close()
        tab118.close()
        
        tab7 = open('grades/k56_mod1/Em_c/omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab119 = open('grades/k56_mod1/Em_c/2omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab120 = open('grades/k56_mod1/Em_c/3omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab121 = open('grades/k56_mod1/Em_c/4omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab7.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab7.write(str(semi_k56_1_c - delta_k56_1_c + i*esp_k56_1_c) + '\n')
        tab7.write(str(j*esp_exc) +'\n')
        tab7.write('5.98'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'-178.0')
        tab119.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab119.write(str(semi_k56_1_c - delta_k56_1_c + i*esp_k56_1_c) + '\n')
        tab119.write(str(j*esp_exc) +'\n')
        tab119.write('5.98'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'-178.0')
        tab120.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab120.write(str(semi_k56_1_c - delta_k56_1_c + i*esp_k56_1_c) + '\n')
        tab120.write(str(j*esp_exc) +'\n')
        tab120.write('5.98'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'-178.0')
        tab121.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab121.write(str(semi_k56_1_c - delta_k56_1_c + i*esp_k56_1_c) + '\n')
        tab121.write(str(j*esp_exc) +'\n')
        tab121.write('5.98'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'-178.0')
        
        tab7.close()
        tab119.close()
        tab120.close()
        tab121.close()
        
        tab8 = open('grades/k56_mod2/Em_c/omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab122 = open('grades/k56_mod2/Em_c/2omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab123 = open('grades/k56_mod2/Em_c/3omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab124 = open('grades/k56_mod2/Em_c/4omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab8.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab8.write(str(semi_k56_2_c - delta_k56_2_c + i*esp_k56_2_c) + '\n')
        tab8.write(str(j*esp_exc) +'\n')
        tab8.write('5.98'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'-178.0')
        tab122.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab122.write(str(semi_k56_2_c - delta_k56_2_c + i*esp_k56_2_c) + '\n')
        tab122.write(str(j*esp_exc) +'\n')
        tab122.write('5.98'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'-178.0')
        tab123.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab123.write(str(semi_k56_2_c - delta_k56_2_c + i*esp_k56_2_c) + '\n')
        tab123.write(str(j*esp_exc) +'\n')
        tab123.write('5.98'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'-178.0')
        tab124.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab124.write(str(semi_k56_2_c - delta_k56_2_c + i*esp_k56_2_c) + '\n')
        tab124.write(str(j*esp_exc) +'\n')
        tab124.write('5.98'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'-178.0')
        
        tab8.close()
        tab122.close()
        tab123.close()
        tab124.close()
        
        tab9 = open('grades/k56_mod1/Em_d/M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab125 = open('grades/k56_mod1/Em_d/2M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab126 = open('grades/k56_mod1/Em_d/3M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab127 = open('grades/k56_mod1/Em_d/4M60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab9.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab9.write(str(semi_k56_1_d - delta_k56_1_d + i*esp_k56_1_d) + '\n')
        tab9.write(str(j*esp_exc) +'\n')
        tab9.write('0.0d0'+'\n'+'0.0d0'+'\n'+'-15.0d0'+'\n'+'-09.6314434344')
        tab125.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab125.write(str(semi_k56_1_d - delta_k56_1_d + i*esp_k56_1_d) + '\n')
        tab125.write(str(j*esp_exc) +'\n')
        tab125.write('0.0d0'+'\n'+'0.0d0'+'\n'+'-15.0d0'+'\n'+'-09.6314434344')
        tab126.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab126.write(str(semi_k56_1_d - delta_k56_1_d + i*esp_k56_1_d) + '\n')
        tab126.write(str(j*esp_exc) +'\n')
        tab126.write('0.0d0'+'\n'+'0.0d0'+'\n'+'-15.0d0'+'\n'+'-09.6314434344')
        tab127.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab127.write(str(semi_k56_1_d - delta_k56_1_d + i*esp_k56_1_d) + '\n')
        tab127.write(str(j*esp_exc) +'\n')
        tab127.write('0.0d0'+'\n'+'0.0d0'+'\n'+'-15.0d0'+'\n'+'-09.6314434344')
        
        tab9.close()
        tab125.close()
        tab126.close()
        tab127.close()
        
        tab10 = open('grades/k56_mod2/Em_d/M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab128 = open('grades/k56_mod2/Em_d/2M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab129 = open('grades/k56_mod2/Em_d/3M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab130 = open('grades/k56_mod2/Em_d/4M60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab10.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab10.write(str(semi_k56_2_d - delta_k56_2_d + i*esp_k56_2_d) + '\n')
        tab10.write(str(j*esp_exc) +'\n')
        tab10.write('30.0d0'+'\n'+'0.0d0'+'\n'+'-15.0d0'+'\n'+'-09.6314434344')
        tab128.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab128.write(str(semi_k56_2_d - delta_k56_2_d + i*esp_k56_2_d) + '\n')
        tab128.write(str(j*esp_exc) +'\n')
        tab128.write('30.0d0'+'\n'+'0.0d0'+'\n'+'-15.0d0'+'\n'+'-09.6314434344')
        tab129.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab129.write(str(semi_k56_2_d - delta_k56_2_d + i*esp_k56_2_d) + '\n')
        tab129.write(str(j*esp_exc) +'\n')
        tab129.write('30.0d0'+'\n'+'0.0d0'+'\n'+'-15.0d0'+'\n'+'-09.6314434344')
        tab130.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab130.write(str(semi_k56_2_d - delta_k56_2_d + i*esp_k56_2_d) + '\n')
        tab130.write(str(j*esp_exc) +'\n')
        tab130.write('30.0d0'+'\n'+'0.0d0'+'\n'+'-15.0d0'+'\n'+'-09.6314434344')
        
        tab10.close()
        tab128.close()
        tab129.close()
        tab130.close()
        
        tab11 = open('grades/k56_mod1/Em_d/omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab131 = open('grades/k56_mod1/Em_d/2omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab132 = open('grades/k56_mod1/Em_d/3omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab133 = open('grades/k56_mod1/Em_d/4omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab11.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab11.write(str(semi_k56_1_d - delta_k56_1_d + i*esp_k56_1_d) + '\n')
        tab11.write(str(j*esp_exc) +'\n')
        tab11.write('0.0d0'+'\n'+'0.0d0'+'\n'+'45.0d0'+'\n'+'-69.6314434344')
        tab131.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab131.write(str(semi_k56_1_d - delta_k56_1_d + i*esp_k56_1_d) + '\n')
        tab131.write(str(j*esp_exc) +'\n')
        tab131.write('0.0d0'+'\n'+'0.0d0'+'\n'+'45.0d0'+'\n'+'-69.6314434344')
        tab132.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab132.write(str(semi_k56_1_d - delta_k56_1_d + i*esp_k56_1_d) + '\n')
        tab132.write(str(j*esp_exc) +'\n')
        tab132.write('0.0d0'+'\n'+'0.0d0'+'\n'+'45.0d0'+'\n'+'-69.6314434344')
        tab133.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab133.write(str(semi_k56_1_d - delta_k56_1_d + i*esp_k56_1_d) + '\n')
        tab133.write(str(j*esp_exc) +'\n')
        tab133.write('0.0d0'+'\n'+'0.0d0'+'\n'+'45.0d0'+'\n'+'-69.6314434344')
        
        tab11.close()
        tab131.close()
        tab132.close()
        tab133.close()
        
        tab12 = open('grades/k56_mod2/Em_d/omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab134 = open('grades/k56_mod2/Em_d/2omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab135 = open('grades/k56_mod2/Em_d/3omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab136 = open('grades/k56_mod2/Em_d/4omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab12.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab12.write(str(semi_k56_2_d - delta_k56_2_d + i*esp_k56_2_d) + '\n')
        tab12.write(str(j*esp_exc) +'\n')
        tab12.write('30.0d0'+'\n'+'0.0d0'+'\n'+'45.0d0'+'\n'+'-69.6314434344')
        tab134.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab134.write(str(semi_k56_2_d - delta_k56_2_d + i*esp_k56_2_d) + '\n')
        tab134.write(str(j*esp_exc) +'\n')
        tab134.write('30.0d0'+'\n'+'0.0d0'+'\n'+'45.0d0'+'\n'+'-69.6314434344')
        tab135.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab135.write(str(semi_k56_2_d - delta_k56_2_d + i*esp_k56_2_d) + '\n')
        tab135.write(str(j*esp_exc) +'\n')
        tab135.write('30.0d0'+'\n'+'0.0d0'+'\n'+'45.0d0'+'\n'+'-69.6314434344')
        tab136.write('3.888912182e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab136.write(str(semi_k56_2_d - delta_k56_2_d + i*esp_k56_2_d) + '\n')
        tab136.write(str(j*esp_exc) +'\n')
        tab136.write('30.0d0'+'\n'+'0.0d0'+'\n'+'45.0d0'+'\n'+'-69.6314434344')
        
        tab12.close()
        tab134.close()
        tab135.close()
        tab136.close()
        
        tab13 = open('grades/k9/Em_d/M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab137 = open('grades/k9/Em_d/2M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab138 = open('grades/k9/Em_d/3M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab139 = open('grades/k9/Em_d/4M60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab13.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab13.write(str(semi_k9_d - delta_k9_d + i*esp_k9_d) + '\n')
        tab13.write(str(j*esp_exc) +'\n')
        tab13.write('0.0d0'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'60.0d0')
        tab137.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab137.write(str(semi_k9_d - delta_k9_d + i*esp_k9_d) + '\n')
        tab137.write(str(j*esp_exc) +'\n')
        tab137.write('0.0d0'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'60.0d0')
        tab138.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab138.write(str(semi_k9_d - delta_k9_d + i*esp_k9_d) + '\n')
        tab138.write(str(j*esp_exc) +'\n')
        tab138.write('0.0d0'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'60.0d0')
        tab139.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab139.write(str(semi_k9_d - delta_k9_d + i*esp_k9_d) + '\n')
        tab139.write(str(j*esp_exc) +'\n')
        tab139.write('0.0d0'+'\n'+'0.0d0'+'\n'+'0.0d0'+'\n'+'60.0d0')
        
        tab13.close()
        tab137.close()
        tab138.close()
        tab139.close()
        
        tab14 = open('grades/k9/Em_d/omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab140 = open('grades/k9/Em_d/2omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab141 = open('grades/k9/Em_d/3omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab142 = open('grades/k9/Em_d/4omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab14.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab14.write(str(semi_k9_d - delta_k9_d + i*esp_k9_d) + '\n')
        tab14.write(str(j*esp_exc) +'\n')
        tab14.write('0.0d0'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'0.0d0')
        tab140.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab140.write(str(semi_k9_d - delta_k9_d + i*esp_k9_d) + '\n')
        tab140.write(str(j*esp_exc) +'\n')
        tab140.write('0.0d0'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'0.0d0')
        tab141.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab141.write(str(semi_k9_d - delta_k9_d + i*esp_k9_d) + '\n')
        tab141.write(str(j*esp_exc) +'\n')
        tab141.write('0.0d0'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'0.0d0')
        tab142.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab142.write(str(semi_k9_d - delta_k9_d + i*esp_k9_d) + '\n')
        tab142.write(str(j*esp_exc) +'\n')
        tab142.write('0.0d0'+'\n'+'0.0d0'+'\n'+'60.0d0'+'\n'+'0.0d0')
        
        tab14.close()
        tab140.close()
        tab141.close()
        tab142.close()
        
        tab15 = open('grades/k9/Em_b/M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab143 = open('grades/k9/Em_b/2M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab144 = open('grades/k9/Em_b/3M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab145 = open('grades/k9/Em_b/4M60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab15.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab15.write(str(semi_k9_b - delta_k9_b + i*esp_k9_b) + '\n')
        tab15.write(str(j*esp_exc) +'\n')
        tab15.write('2.9'+'\n'+'0.0d0'+'\n'+'356.9'+'\n'+'60.0d0')
        tab143.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab143.write(str(semi_k9_b - delta_k9_b + i*esp_k9_b) + '\n')
        tab143.write(str(j*esp_exc) +'\n')
        tab143.write('2.9'+'\n'+'0.0d0'+'\n'+'356.9'+'\n'+'60.0d0')
        tab144.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab144.write(str(semi_k9_b - delta_k9_b + i*esp_k9_b) + '\n')
        tab144.write(str(j*esp_exc) +'\n')
        tab144.write('2.9'+'\n'+'0.0d0'+'\n'+'356.9'+'\n'+'60.0d0')
        tab145.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab145.write(str(semi_k9_b - delta_k9_b + i*esp_k9_b) + '\n')
        tab145.write(str(j*esp_exc) +'\n')
        tab145.write('2.9'+'\n'+'0.0d0'+'\n'+'356.9'+'\n'+'60.0d0')
        
        tab15.close()
        tab143.close()
        tab144.close()
        tab145.close()
        
        tab16 = open('grades/k9/Em_b/omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab146 = open('grades/k9/Em_b/2omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab147 = open('grades/k9/Em_b/3omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab148 = open('grades/k9/Em_b/4omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab16.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab16.write(str(semi_k9_b - delta_k9_b + i*esp_k9_b) + '\n')
        tab16.write(str(j*esp_exc) +'\n')
        tab16.write('2.9'+'\n'+'0.0d0'+'\n'+'56.9'+'\n'+'0.0d0')
        tab146.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab146.write(str(semi_k9_b - delta_k9_b + i*esp_k9_b) + '\n')
        tab146.write(str(j*esp_exc) +'\n')
        tab146.write('2.9'+'\n'+'0.0d0'+'\n'+'56.9'+'\n'+'0.0d0')
        tab147.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab147.write(str(semi_k9_b - delta_k9_b + i*esp_k9_b) + '\n')
        tab147.write(str(j*esp_exc) +'\n')
        tab147.write('2.9'+'\n'+'0.0d0'+'\n'+'56.9'+'\n'+'0.0d0')
        tab148.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab148.write(str(semi_k9_b - delta_k9_b + i*esp_k9_b) + '\n')
        tab148.write(str(j*esp_exc) +'\n')
        tab148.write('2.9'+'\n'+'0.0d0'+'\n'+'56.9'+'\n'+'0.0d0')
        
        tab16.close()
        tab146.close()
        tab147.close()
        tab148.close()
        
        tab17 = open('grades/k9/Em_c/M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab149 = open('grades/k9/Em_c/2M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab150 = open('grades/k9/Em_c/3M60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab151 = open('grades/k9/Em_c/4M60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab17.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab17.write(str(semi_k9_c - delta_k9_c + i*esp_k9_c) + '\n')
        tab17.write(str(j*esp_exc) +'\n')
        tab17.write('2.8'+'\n'+'0.0d0'+'\n'+'169.3'+'\n'+'60.0d0')
        tab149.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab149.write(str(semi_k9_c - delta_k9_c + i*esp_k9_c) + '\n')
        tab149.write(str(j*esp_exc) +'\n')
        tab149.write('2.8'+'\n'+'0.0d0'+'\n'+'169.3'+'\n'+'60.0d0')
        tab150.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab150.write(str(semi_k9_c - delta_k9_c + i*esp_k9_c) + '\n')
        tab150.write(str(j*esp_exc) +'\n')
        tab150.write('2.8'+'\n'+'0.0d0'+'\n'+'169.3'+'\n'+'60.0d0')
        tab151.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab151.write(str(semi_k9_c - delta_k9_c + i*esp_k9_c) + '\n')
        tab151.write(str(j*esp_exc) +'\n')
        tab151.write('2.8'+'\n'+'0.0d0'+'\n'+'169.3'+'\n'+'60.0d0')
        
        tab17.close()
        tab149.close()
        tab150.close()
        tab151.close()

        tab18 = open('grades/k9/Em_c/omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab152 = open('grades/k9/Em_c/2omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab153 = open('grades/k9/Em_c/3omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        tab154 = open('grades/k9/Em_c/4omega60/troiano%003d'%(i + npoints*(j-1)),'w')
        
        tab18.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab18.write(str(semi_k9_c - delta_k9_c + i*esp_k9_c) + '\n')
        tab18.write(str(j*esp_exc) +'\n')
        tab18.write('2.8'+'\n'+'0.0d0'+'\n'+'229.3'+'\n'+'0.0d0')
        tab152.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab152.write(str(semi_k9_c - delta_k9_c + i*esp_k9_c) + '\n')
        tab152.write(str(j*esp_exc) +'\n')
        tab152.write('2.8'+'\n'+'0.0d0'+'\n'+'229.3'+'\n'+'0.0d0')
        tab153.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab153.write(str(semi_k9_c - delta_k9_c + i*esp_k9_c) + '\n')
        tab153.write(str(j*esp_exc) +'\n')
        tab153.write('2.8'+'\n'+'0.0d0'+'\n'+'229.3'+'\n'+'0.0d0')
        tab154.write('3.165901312e-04'+'\n'+'8.848212825391e-10'+'\n'+'0.0000425875045560'+'\n'+'-1'+'\n')
        tab154.write(str(semi_k9_c - delta_k9_c + i*esp_k9_c) + '\n')
        tab154.write(str(j*esp_exc) +'\n')
        tab154.write('2.8'+'\n'+'0.0d0'+'\n'+'229.3'+'\n'+'0.0d0')
        
        tab18.close()
        tab152.close()
        tab153.close()
        tab154.close()

# %%
path = '/home/sonic'
os.chdir(path)

# %%
#!bash teste2.sh
# !bash criando_pastas.sh
